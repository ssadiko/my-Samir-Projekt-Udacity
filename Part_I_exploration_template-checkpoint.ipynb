# %% [markdown]
# # (Dataset Exploration Title) # Part I - Ford GoBike Data Exploration
# ## by (Samir Sadikovic)
#
# ## Introduction
# > Introduce the dataset
# The dataset provided consists of bike-sharing trip data from Ford GoBike. This analysis will explore various aspects of the dataset, including trip durations, popular stations, user demographics, and bike usage patterns.
#
# >**Rubric Tip**: Your code should not generate any errors, and should use functions, loops where possible to reduce repetitive code. Prefer to use functions to reuse code statements.
#
# > **Rubric Tip**: Document your approach and findings in markdown cells. Use comments and docstrings in code cells to document the code functionality.
#
# >**Rubric Tip**: Markup cells should have headers and text that organize your thoughts, findings, and what you plan on investigating next.
#
#
#
# ## Preliminary Wrangling

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# %% [markdown]
# > Load in your dataset and describe its properties through the questions below. Try and motivate your exploration goals through this section.

# %%
# Import necessary library
import pandas as pd

# Load the dataset
data = pd.read_csv('C:\\Users\\Admin\\OneDrive\\Communicate Data Findings 2\\fordgobike-tripdata.csv')

# Display the first few rows of the dataset
data.head()
# Out:
#    duration_sec                start_time                  end_time  \
# 0         52185  2019-02-28 17:32:10.1450  2019-03-01 08:01:55.9750
# 1         42521  2019-02-28 18:53:21.7890  2019-03-01 06:42:03.0560
# 2         61854  2019-02-28 12:13:13.2180  2019-03-01 05:24:08.1460
# 3         36490  2019-02-28 17:54:26.0100  2019-03-01 04:02:36.8420
# 4          1585  2019-02-28 23:54:18.5490  2019-03-01 00:20:44.0740
#
#    start_station_id                                start_station_name  \
# 0              21.0  Montgomery St BART Station (Market St at 2nd St)
# 1              23.0                     The Embarcadero at Steuart St
# 2              86.0                           Market St at Dolores St
# 3             375.0                           Grove St at Masonic Ave
# 4               7.0                               Frank H Ogawa Plaza
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# ...

# %%
# Summary statistics
data.describe(include='all')
# Out:
#          duration_sec                start_time                  end_time  \
# count   183412.000000                    183412                    183412
# unique            NaN                    183401                    183397
# top               NaN  2019-02-25 08:52:07.5820  2019-02-11 08:03:22.6020
# freq              NaN                         2                         2
# mean       726.078435                       NaN                       NaN
# std       1794.389780                       NaN                       NaN
# min         61.000000                       NaN                       NaN
# 25%        325.000000                       NaN                       NaN
# 50%        514.000000                       NaN                       NaN
# 75%        796.000000                       NaN                       NaN
# max      85444.000000                       NaN                       NaN
#
#         start_station_id    start_station_name  start_station_latitude  \
# ...

# %%
# Check for missing values
data.isnull().sum()
# Out:
# duration_sec                  0
# start_time                    0
# end_time                      0
# start_station_id            197
# start_station_name          197
# start_station_latitude        0
# start_station_longitude       0
# end_station_id              197
# end_station_name            197
# end_station_latitude          0
# end_station_longitude         0
# bike_id                       0
# user_type                     0
# member_birth_year          8265
# member_gender              8265
# bike_share_for_all_trip       0
# dtype: int64

# %%
# Handling missing values for member_birth_year and member_gender
data['member_birth_year'].fillna(data['member_birth_year'].median(), inplace=True)
data['member_gender'].fillna('Other', inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23120\2772459417.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['member_birth_year'].fillna(data['member_birth_year'].median(), inplace=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23120\2772459417.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.hist(data['duration_sec'] / 60, bins=100, color='skyblue')
plt.xlabel('Trip Duration (minutes)')
plt.ylabel('Frequency')
plt.title('Distribution of Trip Durations')
plt.xlim(0, 60)  # Limiting to 60 minutes for better visualization
plt.show()

# %% [markdown]
# ### Observation: Distribution of Trip Durations
#
# The histogram illustrates the distribution of trip durations in minutes.
#
# - **Majority of Short Trips**: The majority of trips are very short, with most lasting less than 10 minutes. This indicates that users predominantly use the bike-sharing service for short, quick trips.
#
# - **Sharp Decline**: There is a sharp decline in the frequency of trips as the duration increases. Trips lasting between 10 to 20 minutes are significantly fewer in number.
#
# - **Rare Long Trips**: Very few trips last more than 20 minutes, and trips longer than 30 minutes are quite rare. This suggests that the bike-sharing service is mainly used for short distances or quick errands rather than long-distance travel.
#
# ### Interpretation:
# The distribution shows that the bike-sharing service is primarily utilized for short trips, likely for last-mile connectivity, quick errands, or short commutes within the city. The low frequency of long trips could be due to pricing policies, physical exertion, or availability of other modes of transport for longer distances.
#
# ### Further Analysis:
# To gain deeper insights, we could examine:
# - The relationship between trip duration and time of day to see if longer trips are more common during certain periods.
# - The correlation between trip duration and user demographics (e.g., age, gender) to identify if specific groups tend to take longer or shorter trips.
# - Usage patterns by location to determine if certain areas have longer or shorter trips on average.

# %% [markdown]
# ### Conclusion on the Distribution of Trip Durations
#
# The histogram shows the distribution of trip durations in minutes for the Ford GoBike data. Here are some key insights:
#
# 1. **Short Trips Dominate**:
#    - The vast majority of trips are less than 10 minutes long. This indicates that users primarily use the bikes for short distances.
#    - More than 140,000 trips fall into this range, suggesting that the system is mainly utilized for quick, short trips.
#
# 2. **Longer Trips Are Rare**:
#    - There are very few trips that last longer than 10 minutes. The frequency drops significantly around the 20-minute mark.
#    - Trips lasting more than 30 minutes are very rare, and trips up to 60 minutes are almost non-existent.
#
# 3. **Limited Use for Long-Distance Travel**:
#    - The rare longer trips might indicate specific situations or user groups that use the bikes for leisure or longer commutes.
#
# ### Interpretation:
# This distribution is typical for urban bike-sharing systems, often used by commuters for short distances between subway stations, bus stops, and workplaces. The high frequency of short trips suggests that users mainly value the convenience and flexibility of the bike-sharing system for quick, time-saving rides.
#
# ### Further Analysis:
# To gain deeper insights, we could examine:
# - Whether certain weekdays or times of day (e.g., rush hours) have higher frequencies of short trips.
# - Usage patterns between different user groups (e.g., subscribers vs. one-time customers).
# - The geographical distribution of trips to identify popular routes or stations.

# %%
import seaborn as sb

plt.figure(figsize=(12, 6))
start_stations = data['start_station_name'].value_counts().head(10)
sb.barplot(y=start_stations.index, x=start_stations.values, palette='viridis')
plt.xlabel('Number of Trips')
plt.ylabel('Start Station')
plt.title('Top 10 Start Stations')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23120\4060510551.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.barplot(y=start_stations.index, x=start_stations.values, palette='viridis')

# %% [markdown]
# ### Observation: Top 10 Start Stations
#
# The bar chart illustrates the top 10 start stations based on the number of trips initiated from each station.
#
# - **Most Popular Start Station**: Market St at 10th St is the most popular start station with the highest number of trips.
# - **High Utilization of Key Locations**: Several BART stations such as Montgomery St BART Station and Powell St BART Station are among the top start locations, indicating high usage by commuters.
# - **San Francisco Caltrain Stations**: Both San Francisco Caltrain Station 2 (Townsend St at 4th St) and San Francisco Caltrain (Townsend St at 4th St) are in the top 10, showing significant usage by users commuting to and from the Caltrain stations.
#
# ### Interpretation:
# The top start stations are mostly located in central and highly connected areas, which indicates that users are likely using the bike-sharing service for last-mile connectivity from major transit hubs or popular areas within the city.
#
# ### Further Analysis:
# To gain deeper insights, we could examine:
# - The correlation between the start station and the end station to understand popular routes.
# - The distribution of trip durations from these top start stations to see if they differ significantly.
# - The time of day when these start stations are most utilized to identify peak usage periods.

# %% [markdown]
# ### Conclusion on the Top 10 Start Stations
#
# The bar chart shows the top 10 most frequently used start stations for Ford GoBike trips. Here are some key insights:
#
# 1. **Market St at 10th St**:
#    - This station is the most popular starting point, with nearly 4,000 trips starting from here. This indicates a high demand for bike-sharing services in this area, possibly due to its proximity to key transit hubs or commercial areas.
#
# 2. **San Francisco Caltrain Station 2 (Townsend St at 4th St)**:
#    - The second most popular station, with a substantial number of trips, suggests that many users start their trips near major transportation hubs.
#
# 3. **Other Popular Stations**:
#    - Stations like Berry St at 4th St, Montgomery St BART Station, and Powell St BART Station also rank high in terms of trip frequency. These stations are likely located near important transit points and business districts, catering to commuters and short-distance travelers.
#
# 4. **Concentration of Popular Stations**:
#    - The majority of the top start stations are clustered around major transit hubs and commercial areas in San Francisco. This pattern highlights the importance of integrating bike-sharing systems with public transportation networks.
#
# ### Interpretation:
# The high usage of these start stations indicates that Ford GoBike is effectively serving the needs of commuters and urban travelers in busy areas. The integration of bike-sharing with other forms of public transportation is critical for its success, as evidenced by the popularity of stations near transit hubs.
#
# ### Further Analysis:
# To gain deeper insights, we could examine:
# - The end stations corresponding to these popular start stations to understand common travel routes.
# - The times of day when these stations are most frequently used to identify peak usage periods.
# - User demographics and trip durations starting from these stations to understand the user base and their travel patterns.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def set_labels(x_label, y_label, title):
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Define a function to set axis labels and title
def set_labels(x_label, y_label, title):
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)

# Load the dataset into a pandas dataframe
data_path = 'C:/Users/Admin/OneDrive/Communicate Data Findings 2/fordgobike-tripdata.csv'
data = pd.read_csv(data_path)

# Calculate the age from the birth year
data['age'] = 2024 - data['member_birth_year']

# Plotting the age distribution of users
plt.figure(figsize=(12, 6))
plt.hist(data['age'], bins=20, color='orange', edgecolor='black')
set_labels('Age', 'Frequency', 'Age Distribution of Users')
plt.show()

# %% [markdown]
# Observations:
# The age distribution shows that most users are in their 20s and 30s, with a gradual decline in the number of users in higher age groups. There are very few users over 60 years old. This indicates that younger adults are the primary users of the bike-sharing service.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plotting the gender distribution
plt.figure(figsize=(12, 6))
gender_counts = data['member_gender'].value_counts()
sns.barplot(x=gender_counts.index, y=gender_counts.values, palette='pastel')
set_labels('Gender', 'Number of Users', 'Gender Distribution of Users')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7632\3083441157.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=gender_counts.index, y=gender_counts.values, palette='pastel')

# %% [markdown]
# Observations:
# The bar plot shows the gender distribution of users. The majority of users are male, followed by female users, with a small portion of users identifying as other genders. This indicates that the bike-sharing service is more popular among male users.
#
# By examining these visualizations, we can gain insights into the demographic characteristics of the users of the bike-sharing service.

# %% [markdown]
# ### Conclusion on User Demographics
#
# #### Age Distribution of Users
#
# The histogram shows the age distribution of Ford GoBike users. Here are some key insights:
#
# 1. **Younger Users Dominate**:
#    - The majority of users are between 20 and 40 years old, with most users in their late 20s and early 30s. This suggests that younger adults are the primary users of the bike-sharing service.
#    - The highest frequency is around 30 years old, indicating that this age group is the most active.
#
# 2. **Decreasing Usage with Age**:
#    - The number of users steadily decreases with increasing age. Users over 50 years old are significantly less represented compared to younger users.
#    - There are very few users older than 60, suggesting that older adults are less likely to use this service.
#
# 3. **Outliers in Higher Age Groups**:
#    - There are a few users who are significantly older, even over 100 years old. These could be data entry errors or unusual cases.
#
# **Interpretation**:
# The age distribution shows that Ford GoBike is primarily used by younger adults, likely due to their higher mobility and acceptance of new technologies. The decreasing usage with age could be due to various factors such as physical fitness, technological affinity, and mobility needs.
#
# **Further Analysis**:
# To gain deeper insights, we could examine:
# - Usage patterns across different age groups, such as average trip duration and distance traveled.
# - The geographical distribution of trips by age group to identify popular routes for different age segments.
# - Differences in usage frequency between subscribers and casual users across various age groups.
#
# #### Gender Distribution of Users
#
# The bar plot shows the gender distribution of Ford GoBike users. Here are some key insights:
#
# 1. **Male Users Dominate**:
#    - The majority of users are male, followed by female users, with a small portion of users identifying as other genders. This suggests that the bike-sharing service is more popular among male users.
#
# 2. **Gender Distribution**:
#    - There is a noticeable gap between male and female users, indicating a potential area for targeted marketing or service adjustments to attract more female users.
#
# **Interpretation**:
# The gender distribution suggests that Ford GoBike has a higher adoption rate among men. This could be due to various factors such as perceived safety, convenience, and marketing efforts. Understanding the reasons behind this gender disparity can help tailor strategies to attract more female users.
#
# **Further Analysis**:
# To gain deeper insights, we could examine:
# - Usage patterns across different genders, such as average trip duration and distance traveled.
# - The geographical distribution of trips by gender to identify popular routes for different user segments.
# - Differences in usage frequency between subscribers and casual users across different genders.
# - Conduct surveys or focus groups to understand the preferences and concerns of different gender groups regarding bike-sharing services.

# %%
# Convert start_time and end_time to datetime
data['start_time'] = pd.to_datetime(data['start_time'])
data['end_time'] = pd.to_datetime(data['end_time'])

# Extract hour from start_time
data['start_hour'] = data['start_time'].dt.hour
plt.figure(figsize=(12, 6))
start_hour_counts = data['start_hour'].value_counts().sort_index()
sb.barplot(x=start_hour_counts.index, y=start_hour_counts.values, palette='coolwarm')
plt.xlabel('Hour of the Day')
plt.ylabel('Number of Trips')
plt.title('Distribution of Trip Start Times by Hour')
plt.show()

# Extract day of the week from start_time
data['start_day'] = data['start_time'].dt.day_name()
plt.figure(figsize=(12, 6))
start_day_counts = data['start_day'].value_counts().reindex(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
sb.barplot(x=start_day_counts.index, y=start_day_counts.values, palette='coolwarm')
plt.xlabel('Day of the Week')
plt.ylabel('Number of Trips')
plt.title('Distribution of Trip Start Times by Day of the Week')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7632\57014788.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.barplot(x=start_hour_counts.index, y=start_hour_counts.values, palette='coolwarm')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7632\57014788.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.barplot(x=start_day_counts.index, y=start_day_counts.values, palette='coolwarm')

# %% [markdown]
# ### Observations on Trip Start Times by Hour and Day of the Week
#
# #### Distribution of Trip Start Times by Hour
#
# The bar plot shows the distribution of trip start times by hour. Here are some key insights:
#
# 1. **Peak Hours**:
#    - The highest number of trips start during the morning and evening commuting hours of 8 AM and 5 PM, respectively.
#    - Another noticeable peak is at 6 PM, likely indicating after-work activities.
#
# 2. **Midday Usage**:
#    - There is a significant number of trips starting around midday (12 PM), suggesting usage for lunch breaks or midday activities.
#
# 3. **Low Usage Periods**:
#    - Early morning hours (midnight to 6 AM) have significantly lower trip counts, indicating fewer people use the service at these times.
#
# **Interpretation**:
# These patterns suggest that Ford GoBike is predominantly used for commuting and work-related activities. The service sees its highest demand during traditional commuting hours, highlighting its role in daily transportation for many users.
#
# #### Distribution of Trip Start Times by Day of the Week
#
# The bar plot shows the distribution of trip start times by day of the week. Here are some key insights:
#
# 1. **Weekday Usage**:
#    - The highest number of trips occur on weekdays, with Thursday being the peak day.
#    - Monday through Friday have consistently high usage, supporting the observation that the service is mainly used for commuting.
#
# 2. **Weekend Usage**:
#    - There is a noticeable drop in usage on weekends, with Saturday having the lowest number of trips.
#    - This indicates fewer people use the service for recreational purposes on weekends compared to weekday commuting.
#
# **Interpretation**:
# The distribution of trip start times by day of the week reinforces the observation that Ford GoBike is primarily used for weekday commuting. The lower weekend usage suggests that while some users might use the service for leisure, the primary function is to support daily commutes during the workweek.
#
# These insights can guide operational strategies, such as bike placement and maintenance scheduling, to better match peak usage periods and enhance service efficiency.

# %% [markdown]
# ### Conclusion on the Distribution of Trip Start Times
#
# #### Distribution of Trip Start Times by Hour
#
# The bar chart shows the distribution of trip start times by hour of the day. Here are some key insights:
#
# 1. **Morning Peak Hours**:
#    - There is a significant increase in trips during the early morning hours, especially around 8 AM. This suggests that many users are using the bikes for their morning commutes to work or school.
#
# 2. **Evening Peak Hours**:
#    - Another significant increase in trips is observed in the early evening hours around 5 PM. This corresponds to the end of a typical workday, indicating that many users are using the bikes for their commute home.
#
# 3. **Low Usage During Night**:
#    - The usage of bikes is very low between midnight and 6 AM. This is expected as most people are likely sleeping or using other forms of transportation during these hours.
#
# ### Interpretation:
# The distribution of trip start times by hour shows two main peak times that align with typical morning and evening commute hours. This indicates that Ford GoBike is frequently used for commuting purposes.
#
# ### Further Analysis:
# - Investigate usage patterns on weekends compared to weekdays to identify differences in travel habits.
# - Analyze trip start times for different age groups and genders to identify specific usage trends.
#
# ---
#
# #### Distribution of Trip Start Times by Day of the Week
#
# The bar chart shows the distribution of trip start times by day of the week. Here are some key insights:
#
# 1. **Highest Usage on Weekdays**:
#    - The number of trips is highest on weekdays (especially Thursday). This supports the observation that many users are using the bikes for daily commutes.
#    - Usage remains relatively high and consistent on most weekdays.
#
# 2. **Lower Usage on Weekends**:
#    - The number of trips significantly decreases on weekends (Saturday and Sunday). This could indicate that fewer people are commuting to work and may be using the bikes for leisure or not at all.
#
# ### Interpretation:
# The distribution of trip start times by day of the week shows higher usage on weekdays, indicating that Ford GoBike is primarily used by commuters. The lower usage on weekends suggests a shift in usage patterns.
#
# ### Further Analysis:
# - Investigate usage patterns on holidays compared to regular weekdays.
# - Analyze trip start times by day of the week for different user groups (e.g., subscribers vs. casual users).

# %% [markdown]
# ### What is the structure of your dataset?
#
# > Your answer here!The dataset consists of the following columns:
# - **duration_sec**: Duration of the trip in seconds.
# - **start_time**: Start timestamp of the trip.
# - **end_time**: End timestamp of the trip.
# - **start_station_id**: ID of the starting station.
# - **start_station_name**: Name of the starting station.
# - **start_station_latitude**: Latitude of the starting station.
# - **start_station_longitude**: Longitude of the starting station.
# - **end_station_id**: ID of the ending station.
# - **end_station_name**: Name of the ending station.
# - **end_station_latitude**: Latitude of the ending station.
# - **end_station_longitude**: Longitude of the ending station.
# - **bike_id**: ID of the bike used for the trip.
# - **user_type**: Type of user (Customer or Subscriber).
# - **member_birth_year**: Birth year of the member.
# - **member_gender**: Gender of the member.
# - **bike_share_for_all_trip**: Whether the bike was part of the Bike Share for All program.
#
# ### What is/are the main feature(s) of interest in your dataset?
#
# > Your answer here!- **Trip Duration**: To understand how long trips typically last.
# - **Popular Stations**: To identify the most frequently used start and end stations.
# - **User Demographics**: To gain insights into the demographics of the users, including age distribution and gender.
# - **Bike Usage Patterns**: To identify patterns in bike usage, including the most frequently used bikes.
# - **Trip Times**: To analyze common times of day for trips to start and end.
#
# ### What features in the dataset do you think will help support your investigation into your feature(s) of interest?
#
# > Your answer here!- **duration_sec**: To analyze trip durations.
# - **start_station_name** and **end_station_name**: To identify popular stations.
# - **user_type**, **member_birth_year**, and **member_gender**: To explore user demographics.
# - **bike_id**: To examine bike usage patterns.
# - **start_time** and **end_time**: To analyze trip times.

# %% [markdown]
# ## Univariate Exploration
#
# > In this section, investigate distributions of individual variables. If
# you see unusual points or outliers, take a deeper look to clean things up
# and prepare yourself to look at relationships between variables.
#
#
# > **Rubric Tip**: The project (Parts I alone) should have at least 15 visualizations distributed over univariate, bivariate, and multivariate plots to explore many relationships in the data set.  Use reasoning to justify the flow of the exploration.
#
#
#
# >**Rubric Tip**: Use the "Question-Visualization-Observations" framework  throughout the exploration. This framework involves **asking a question from the data, creating a visualization to find answers, and then recording observations after each visualisation.**

# %%
import seaborn as sb
import matplotlib.pyplot as plt

def set_labels(x_label, y_label, title):
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)

# Plotting the top 10 start stations
plt.figure(figsize=(12, 6))
start_stations = data['start_station_name'].value_counts().head(10)
sb.barplot(y=start_stations.index, x=start_stations.values, palette='viridis')
set_labels('Number of Trips', 'Start Station', 'Top 10 Start Stations')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7632\3162982649.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.barplot(y=start_stations.index, x=start_stations.values, palette='viridis')

# %% [markdown]
# ### Top 10 Start Stations
#
# The bar plot above shows the top 10 start stations for Ford GoBike users. Here are some key insights:
#
# 1. **Most Popular Start Station**:
#    - The most popular start station is "Market St at 10th St", with the highest number of trips starting from this location.
#
# 2. **High Usage at Transit Hubs**:
#    - Several stations with high trip counts are located near major transit hubs, such as "San Francisco Caltrain Station 2 (Townsend St at 4th St)" and "Powell St BART Station (Market St at 4th St)". This indicates that many users begin their trips at locations that connect with other forms of transportation.
#
# 3. **Concentration in Central Areas**:
#    - The top start stations are primarily located in central areas of the city, suggesting that these areas have a higher demand for bike-sharing services.
#
# **Interpretation**:
# These patterns indicate that Ford GoBike is widely used in central locations and near major transit hubs, reinforcing its role in providing first-mile and last-mile connectivity for commuters. This information can help in planning the distribution of bikes and stations to meet high demand areas effectively.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset into a pandas dataframe
data_path = 'C:/Users/Admin/OneDrive/Communicate Data Findings 2/fordgobike-tripdata.csv'
data = pd.read_csv(data_path)

# Creating a new column 'age' from 'member_birth_year'
data['age'] = 2019 - data['member_birth_year']

# Plotting the age distribution
plt.figure(figsize=(12, 6))
plt.hist(data['age'].dropna(), bins=30, color='coral')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution of Users')
plt.show()

# %% [markdown]
# ### Conclusion on User Demographics
#
# #### Age Distribution of Users
#
# The histogram shows the age distribution of Ford GoBike users. Here are some key insights:
#
# 1. **Younger Users Dominate**:
#    - The majority of users are between 20 and 40 years old, with most users in their late 20s and early 30s. This suggests that younger adults are the primary users of the bike-sharing service.
#    - The highest frequency is around 30 years old, indicating that this age group is the most active.
#
# 2. **Decreasing Usage with Age**:
#    - The number of users steadily decreases with increasing age. Users over 50 years old are significantly less represented compared to younger users.
#    - There are very few users older than 60, suggesting that older adults are less likely to use this service.
#
# 3. **Outliers in Higher Age Groups**:
#    - There are a few users who are significantly older, even over 100 years old. These could be data entry errors or unusual cases.
#
# ### Interpretation:
# The age distribution shows that Ford GoBike is primarily used by younger adults, likely due to their higher mobility and acceptance of new technologies. The decreasing usage with age could be due to various factors such as physical fitness, technological affinity, and mobility needs.
#
# ### Further Analysis:
# To gain deeper insights, we could examine:
# - Usage patterns across different age groups, such as average trip duration and distance traveled.
# - The geographical distribution of trips by age group to identify popular routes for different age segments.
# - Differences in usage frequency between subscribers and casual users across various age groups.

# %%
import matplotlib.pyplot as plt
import seaborn as sb
import pandas as pd

# Define the set_labels function once
def set_labels(x_label, y_label, title):
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)

# Load the dataset into a pandas dataframe
data_path = 'C:/Users/Admin/OneDrive/Communicate Data Findings 2/fordgobike-tripdata.csv'
data = pd.read_csv(data_path)

# Calculate the age from the birth year
data['age'] = 2024 - data['member_birth_year']

# Plotting the gender distribution
plt.figure(figsize=(12, 6))
gender_counts = data['member_gender'].value_counts()
sb.barplot(x=gender_counts.index, y=gender_counts.values, palette='pastel')
set_labels('Gender', 'Number of Users', 'Gender Distribution of Users')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6992\1955540700.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.barplot(x=gender_counts.index, y=gender_counts.values, palette='pastel')

# %% [markdown]
# #### Gender Distribution of Users
#
# The bar chart shows the gender distribution of Ford GoBike users. Here are some key insights:
#
# 1. **Male Dominance**:
#    - The majority of users are male, with a significantly higher number compared to female users.
#    - This indicates that men are more likely to use the bike-sharing service than women.
#
# 2. **Smaller Female User Base**:
#    - Female users make up a smaller portion of the user base compared to male users.
#    - The difference in numbers suggests a potential area for growth by targeting female users.
#
# 3. **Other Genders**:
#    - A small number of users identify as a gender other than male or female.
#    - This category is significantly less represented, which might be due to various reasons including societal norms and data recording practices.
#
# ### Interpretation:
# The gender distribution highlights a clear male dominance in the usage of Ford GoBike. Efforts to attract more female users could help balance the user base and potentially increase overall ridership.
#
# ### Further Analysis:
# To gain deeper insights, we could examine:
# - The differences in trip characteristics (e.g., duration, distance) between male and female users.
# - The geographical distribution of trips by gender to identify popular routes for each gender.
# - Marketing strategies to attract a more balanced gender representation among users.

# %%
# Plotting the top 10 most used bikes
plt.figure(figsize=(12, 6))
bike_usage = data['bike_id'].value_counts().head(10)
sb.barplot(y=bike_usage.index, x=bike_usage.values, palette='coolwarm')
plt.xlabel('Number of Trips')
plt.ylabel('Bike ID')
plt.title('Top 10 Most Used Bikes')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7632\586303112.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.barplot(y=bike_usage.index, x=bike_usage.values, palette='coolwarm')

# %% [markdown]
# #### Top 10 Most Used Bikes
#
# The bar chart shows the top 10 most used bikes in the Ford GoBike system. Here are some key insights:
#
# 1. **Consistent Usage Across Top Bikes**:
#    - The top 10 bikes have been used for a significant number of trips, ranging from around 4,500 to over 5,000 trips.
#    - This indicates that these bikes are heavily relied upon and are frequently in service.
#
# 2. **Variation in Usage**:
#    - There is some variation in the number of trips among the top 10 bikes, with the most used bike having slightly more trips than the others.
#    - This could be due to factors such as bike condition, location, and user preference.
#
# ### Interpretation:
# The consistent usage of the top 10 bikes suggests a high demand and reliance on these specific bikes. Ensuring these bikes are well-maintained and available can help maintain service reliability and user satisfaction.
#
# ### Further Analysis:
# To gain deeper insights, we could examine:
# - The maintenance history and condition of the top 10 bikes to identify any correlations with usage patterns.
# - The geographical distribution of trips for the top 10 bikes to understand where they are most frequently used.
# - User feedback on the top 10 bikes to identify any specific preferences or issues.

# %%
# Extracting hour from start_time
data['start_hour'] = pd.to_datetime(data['start_time']).dt.hour

# Plotting the distribution of trip start times by hour
plt.figure(figsize=(12, 6))
start_hour_counts = data['start_hour'].value_counts().sort_index()
sb.barplot(x=start_hour_counts.index, y=start_hour_counts.values, palette='coolwarm')
plt.xlabel('Hour of the Day')
plt.ylabel('Number of Trips')
plt.title('Distribution of Trip Start Times by Hour')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7632\2349328043.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.barplot(x=start_hour_counts.index, y=start_hour_counts.values, palette='coolwarm')

# %% [markdown]
# ### Observation: Distribution of Trip Start Times by Hour
#
# The bar chart displays the distribution of trip start times throughout the day, segmented by hour.
#
# - **Morning and Evening Peaks**: The chart reveals two significant peaks in usage:
#   - The first peak occurs in the morning between 7 AM and 9 AM, indicating a high number of trips as people likely commute to work or school.
#   - The second peak is observed in the evening from 4 PM to 6 PM, suggesting a similar commuting pattern for the return journey.
#
# - **Midday and Late-Night Decline**: There is a noticeable decline in trips during midday (11 AM to 3 PM) and late-night hours (10 PM to 5 AM), indicating less frequent use during these times, possibly due to fewer commutes and general inactivity.
#
# - **Consistent Usage in Working Hours**: The hours between the peaks (9 AM to 4 PM) show a relatively consistent number of trips, likely representing non-commute travel such as errands, meetings, or leisure activities.
#
# These insights can help in understanding user behavior patterns and optimizing bike availability during peak hours to meet demand.

# %%
# Extracting day of the week from start_time
data['start_day'] = pd.to_datetime(data['start_time']).dt.day_name()

# Plotting the distribution of trip start times by day of the week
plt.figure(figsize=(12, 6))
start_day_counts = data['start_day'].value_counts().reindex(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
sb.barplot(x=start_day_counts.index, y=start_day_counts.values, palette='coolwarm')
plt.xlabel('Day of the Week')
plt.ylabel('Number of Trips')
plt.title('Distribution of Trip Start Times by Day of the Week')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7632\996225411.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.barplot(x=start_day_counts.index, y=start_day_counts.values, palette='coolwarm')

# %% [markdown]
# ### Observation: Distribution of Trip Start Times by Day of the Week
#
# The bar chart displays the distribution of trip start times throughout the week, segmented by day.
#
# - **Weekday Peaks**: The chart reveals that trip activity is higher on weekdays compared to weekends:
#   - **Thursday** has the highest number of trips, followed closely by **Tuesday** and **Wednesday**.
#   - **Monday** and **Friday** show slightly lower activity compared to the mid-week peak days but are still higher than the weekends.
#
# - **Weekend Decline**: There is a noticeable decline in the number of trips on **Saturday** and **Sunday**, indicating that users primarily use the bike-sharing service for weekday activities, likely commuting or regular errands.
#
# - **Mid-Week Preference**: The preference for mid-week days (Tuesday, Wednesday, Thursday) suggests that users might be balancing their activities and opting for biking on these days for convenience or fitness reasons.
#
# These insights can help in understanding user behavior patterns and optimizing bike availability during peak days to meet demand.

# %% [markdown]
# >**Rubric Tip**: Visualizations should depict the data appropriately so that the plots are easily interpretable. You should choose an appropriate plot type, data encodings, and formatting as needed. The formatting may include setting/adding the title, labels, legend, and comments.

# %% [markdown]
# ### Discuss the distribution(s) of your variable(s) of interest. Were there any unusual points? Did you need to perform any transformations?
#
# ### Discuss the Distribution(s) of Your Variable(s) of Interest
#
# #### Trip Duration
# - The distribution of trip durations is highly skewed to the right, with the majority of trips being short. Most trips are under 10 minutes, indicating that the service is predominantly used for quick commutes.
# - There are some unusually long trips that extend beyond an hour. These outliers could be due to a variety of reasons such as extended use, incorrect docking, or data entry errors. To visualize the distribution more effectively, we limited the trip duration to 60 minutes in some of the plots.
# - Transformations such as logarithmic scaling could be applied to normalize the skewed distribution for more advanced analyses.
#
# #### Age
# - The age distribution of users shows that the majority of users are between 20 and 40 years old, with a peak around 30 years old. This suggests that younger adults are the primary users of the Ford GoBike service.
# - There are a few outliers with ages above 100, which are likely data entry errors. No transformations were applied to the age data, but these outliers should be addressed for more accurate analysis.
#
# #### Start Hour
# - The distribution of trip start times is bimodal, with two clear peaks during the morning (around 8 AM) and evening (around 5 PM) rush hours. This aligns with typical commuting patterns.
# - There is a significant drop in trips during the late night and early morning hours (from 12 AM to 5 AM), which is expected as fewer people are likely to use the service during these times.
# - No transformations were necessary for the start hour data.
#
# #### Gender
# - The gender distribution is heavily skewed towards male users, with significantly fewer female users and an even smaller number of users identifying as other. This imbalance suggests that marketing and outreach efforts could be targeted to increase female participation.
# - No unusual points were noted in the gender distribution, and no transformations were needed.
#
# ### Unusual Points and Transformations
# - **Unusually Long Trip Durations**: There are some trips with durations exceeding an hour, which are outliers compared to the majority of trips. These points were limited in the visualization to improve clarity.
# - **Age Outliers**: Users with ages over 100 are likely data errors and were noted as outliers. These should be cleaned from the dataset for more accurate analysis.
# - **Skewed Distributions**: The highly skewed distributions of trip durations could benefit from transformations such as log scaling to normalize the data for certain types of analyses.
#
# Overall, the distributions provide valuable insights into user behavior and service usage patterns. Addressing the unusual points and considering appropriate transformations can further enhance the quality of the analysis.
# .
#
#
# ### Of the features you investigated, were there any unusual distributions? Did you perform any operations on the data to tidy, adjust, or change the form of the data? If so, why did you do this?
#
#
# #### Unusual Distributions:
# 1. **Trip Duration**:
#    - The distribution of trip durations was highly right-skewed, with most trips being short (under 10 minutes) and a long tail of unusually long trips. This indicated that the majority of users used the service for quick commutes, but there were some outliers with much longer trips.
#    - There were extreme outliers with trip durations extending beyond an hour, which could be due to extended use, docking errors, or data entry issues.
#
# 2. **Age**:
#    - The age distribution showed a peak around 30 years old, with most users between 20 and 40 years old. However, there were some extreme outliers with ages above 100, likely due to data entry errors.
#
# 3. **Gender**:
#    - The gender distribution was heavily skewed towards male users, with a significantly smaller number of female users and even fewer users identifying as other.
#
# 4. **Start Hour**:
#    - The distribution of trip start times showed clear peaks during the morning and evening rush hours (around 8 AM and 5 PM), which aligns with typical commuting patterns. There was a significant drop in usage during late night and early morning hours.
#
# #### Operations Performed:
#
# 1. **Trip Duration**:
#    - To handle the highly skewed distribution of trip durations, we limited the visualization to 60 minutes for better clarity and to focus on the majority of trips. This helped in identifying the main usage patterns without being overshadowed by the extreme outliers.
#    - For advanced analyses, transformations such as logarithmic scaling could be considered to normalize the skewed distribution.
#
# 2. **Age**:
#    - Although no transformations were applied, it was noted that the extreme outliers with ages above 100 should be addressed. These outliers likely represent data entry errors and should be cleaned from the dataset for more accurate analysis.
#
# 3. **Start Hour**:
#    - The data was converted to datetime format to extract the start hour accurately. This allowed us to visualize the distribution of trips across different hours of the day and identify peak usage times.
#
# 4. **Data Cleaning**:
#    - Throughout the analysis, missing values were handled appropriately, and data types were converted as needed (e.g., converting start times to datetime format).
#
# ### Summary:
# - **Trip Duration**: Limited to 60 minutes in visualizations to handle skewness and outliers.
# - **Age**: Noted outliers above 100 years old, indicating the need for data cleaning.
# - **Start Hour**: Extracted from datetime format to visualize peak usage times.
# - **General Cleaning**: Addressed missing values and ensured correct data types.
#
# These operations and adjustments were performed to ensure the accuracy and clarity of the visualizations, allowing for better insights into user behavior and service usage patterns.

# %% [markdown]
# ## Bivariate Exploration
#
# > In this section, investigate relationships between pairs of variables in your
# data. Make sure the variables that you cover here have been introduced in some
# fashion in the previous section (univariate exploration).

# %% [markdown]
#  In this section, investigate relationships between pairs of variables in your data. Make sure the variables that you cover here have been introduced in some fashion in the previous section (univariate exploration).

# %%
## Bivariate Exploration


### Question 1: How does trip duration vary with age?

import matplotlib.pyplot as plt
import seaborn as sb
import pandas as pd

# Define a function to set axis labels and title
def set_labels(x_label, y_label, title):
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)

# Load the dataset into a pandas dataframe
data_path = 'C:/Users/Admin/OneDrive/Communicate Data Findings 2/fordgobike-tripdata.csv'
data = pd.read_csv(data_path)

# Calculate the age from the birth year
data['age'] = 2024 - data['member_birth_year']

# Bin the ages
bins = [0, 20, 30, 40, 50, 60, 70, 80, 90, 100]
labels = ['<20', '20-29', '30-39', '40-49', '50-59', '60-69', '70-79', '80-89', '90-99']
data['age_bin'] = pd.cut(data['age'], bins=bins, labels=labels, right=False)

# Box plot of trip duration by age bin
plt.figure(figsize=(12, 6))
sb.boxplot(data=data, x='age_bin', y='duration_sec')
set_labels('Age Bin', 'Trip Duration (seconds)', 'Trip Duration by Age Bin')
plt.ylim(0, 3600)  # Limiting to 1 hour for better visualization
plt.show()

# %% [markdown]
# Observations:
# With the age data binned, it becomes clearer how trip durations vary across different age groups. Younger users (under 20) and older users (60 and above) tend to have a wider range of trip durations, while the middle age groups have more consistent trip durations. This visualization can provide more actionable insights compared to the initial box plot with individual ages.

# %% [markdown]
# Question 2: How does trip duration vary by gender?

# %%
import matplotlib.pyplot as plt
import seaborn as sb
import pandas as pd

# Define a function to set axis labels and title
def set_labels(x_label, y_label, title):
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)

# Load the dataset into a pandas dataframe
data_path = 'C:/Users/Admin/OneDrive/Communicate Data Findings 2/fordgobike-tripdata.csv'
data = pd.read_csv(data_path)

# Box plot of trip duration by gender
plt.figure(figsize=(12, 6))
sb.boxplot(data=data, x='member_gender', y='duration_sec')
set_labels('Gender', 'Trip Duration (seconds)', 'Trip Duration by Gender')
plt.ylim(0, 3600)  # Limiting to 1 hour for better visualization
plt.show()

# %% [markdown]
# Observations:
# Based on the box plot, it can be observed that trip durations are relatively similarly distributed across all genders. However, there are some outliers with longer trips. The median trip duration appears to be slightly higher for 'Other' gender category compared to 'Male' and 'Female' categories, but overall the distribution does not show significant differences between genders.
#
# This information can be useful in understanding how different gender groups use the bike-sharing service and whether there are any significant differences in their usage patterns.

# %% [markdown]
# Question 3: How does user type relate to trip duration?

# %%
import matplotlib.pyplot as plt
import seaborn as sb
import pandas as pd

# Define a function to set axis labels and title
def set_labels(x_label, y_label, title):
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)

# Load the dataset into a pandas dataframe
data_path = 'C:/Users/Admin/OneDrive/Communicate Data Findings 2/fordgobike-tripdata.csv'
data = pd.read_csv(data_path)

# Box plot of trip duration by user type
plt.figure(figsize=(12, 6))
sb.boxplot(data=data, x='user_type', y='duration_sec')
set_labels('User Type', 'Trip Duration (seconds)', 'Trip Duration by User Type')
plt.ylim(0, 3600)  # Limiting to 1 hour for better visualization
plt.show()

# %% [markdown]
# Observations:
# Based on the box plot, it can be observed that there is a noticeable difference in trip durations between different user types. Subscribers tend to have shorter and more consistent trip durations, while customers show a wider range of trip durations, with some taking significantly longer trips.
#
# This suggests that subscribers might be using the service for regular, shorter commutes, whereas customers may use it for occasional, possibly longer trips. This information can help in understanding the different usage patterns and preferences between subscribers and customers, which can be useful for service optimization and targeted marketing strategies.

# %% [markdown]
# Question 4: What is the relationship between trip start hour and trip duration?

# %%
import matplotlib.pyplot as plt
import seaborn as sb
import pandas as pd

# Define a function to set axis labels and title
def set_labels(x_label, y_label, title):
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)

# Load the dataset into a pandas dataframe
data_path = 'C:/Users/Admin/OneDrive/Communicate Data Findings 2/fordgobike-tripdata.csv'
data = pd.read_csv(data_path)

# Convert the start_time to datetime
data['start_time'] = pd.to_datetime(data['start_time'])

# Extract the start hour from start_time
data['start_hour'] = data['start_time'].dt.hour

# Box plot of trip duration by start hour
plt.figure(figsize=(12, 6))
sb.boxplot(data=data, x='start_hour', y='duration_sec')
set_labels('Hour of the Day', 'Trip Duration (seconds)', 'Trip Duration by Start Hour')
plt.ylim(0, 3600)  # Limiting to 1 hour for better visualization
plt.show()

# %% [markdown]
# Observations:
# Based on the box plot, it can be observed that trip durations vary across different hours of the day. There is a tendency for longer trip durations during late night and early morning hours, possibly indicating more leisurely or recreational use. In contrast, trip durations are shorter and more consistent during typical commuting hours (7-9 AM and 4-6 PM), which suggests that users are primarily using the service for commuting during these times.
#
# This relationship indicates that different times of day see different patterns of use, which could be valuable for optimizing bike availability and managing service demand throughout the day.

# %% [markdown]
# Question 5: How do user age and gender interact?

# %%
import matplotlib.pyplot as plt
import seaborn as sb
import pandas as pd

# Define a function to set axis labels and title
def set_labels(x_label, y_label, title):
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)

# Load the dataset into a pandas dataframe
data_path = 'C:/Users/Admin/OneDrive/Communicate Data Findings 2/fordgobike-tripdata.csv'
data = pd.read_csv(data_path)

# Calculate the age from the birth year
data['age'] = 2024 - data['member_birth_year']

# Plot the distribution of age by gender
plt.figure(figsize=(12, 6))
sb.violinplot(data=data, x='member_gender', y='age', inner='quartile', palette='pastel')
set_labels('Gender', 'Age', 'Age Distribution by Gender')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7632\3312201368.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.violinplot(data=data, x='member_gender', y='age', inner='quartile', palette='pastel')

# %% [markdown]
# Observations:
# The violin plot shows the distribution of ages within each gender category. Here are some observations:
#
# The age distribution for both male and female users is quite similar, with most users falling in the 20-40 age range.
# The 'Other' gender category shows a broader age range compared to 'Male' and 'Female' categories, but the number of users in this category appears to be lower.
# There are some outliers in all categories, indicating users who are significantly younger or older than the majority.
# This visualization helps to understand how age and gender interact among the users of the bike-sharing service. It indicates that the service is predominantly used by younger adults across all gender categories, with some variations in age distribution.

# %% [markdown]
# Add this Markdown text to your Jupyter Notebook to introduce the Bivariate Exploration section and provide structured analyses using questions, visualizations, and observations for each pair of variables.

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. How did the feature(s) of interest vary with other features in the dataset?
#
# > Your answer here!### Talk about some of the relationships you observed in this part of the investigation. How did the feature(s) of interest vary with other features in the dataset?
# ### Talk about some of the relationships you observed in this part of the investigation. How did the feature(s) of interest vary with other features in the dataset?
#
# In this part of the investigation, several interesting relationships between different features in the dataset were observed:
#
# 1. **Trip Duration and Age**:
#    - **Observation**: The box plot of trip duration by age showed that younger users (under 20) and older users (60 and above) tend to have a wider range of trip durations. Middle-aged users have more consistent trip durations.
#    - **Insight**: This suggests that younger and older users may use the bike-sharing service for more varied purposes compared to middle-aged users, who might primarily use it for commuting.
#
# 2. **Trip Duration and Gender**:
#    - **Observation**: The trip duration by gender box plot indicated that trip durations are relatively similarly distributed across all genders, with some outliers showing longer trips. The median trip duration for the 'Other' gender category appeared to be slightly higher.
#    - **Insight**: This indicates that there are no significant differences in trip duration between genders, suggesting similar usage patterns among male, female, and other gender users.
#
# 3. **Trip Duration and User Type**:
#    - **Observation**: The trip duration by user type box plot revealed that subscribers tend to have shorter and more consistent trip durations, while customers have a wider range of trip durations with some significantly longer trips.
#    - **Insight**: Subscribers might be using the service for regular, shorter commutes, whereas customers may use it for occasional, longer trips. This can inform strategies to tailor services and marketing for different user types.
#
# 4. **Trip Duration and Start Hour**:
#    - **Observation**: The box plot of trip duration by start hour showed that trip durations tend to be longer during late night and early morning hours, while they are shorter and more consistent during typical commuting hours (7-9 AM and 4-6 PM).
#    - **Insight**: This indicates different usage patterns at different times of the day, with commuting trips being more common during peak hours and possibly recreational trips during off-peak hours. This can help in optimizing bike availability and managing service demand.
#
# 5. **Age and Gender Interaction**:
#    - **Observation**: The violin plot of age distribution by gender demonstrated that the age distribution for both male and female users is quite similar, with most users falling in the 20-40 age range. The 'Other' gender category showed a broader age range but with fewer users.
#    - **Insight**: The bike-sharing service is predominantly used by younger adults across all gender categories. Understanding this demographic can help in designing targeted marketing campaigns and service improvements.
#
# Overall, these observations highlight the varied usage patterns of the bike-sharing service across different user demographics and time periods. These insights can be valuable for optimizing the service, improving user experience, and tailoring marketing strategies.
#
#
#
#
# ### Did you observe any interesting relationships between the other features (not the main feature(s) of interest)?
#
# > Your answer here!### Did you observe any interesting relationships between the other features (not the main feature(s) of interest)?
#
# During the bivariate exploration, several interesting relationships between other features in the dataset were observed:
#
# ### Did you observe any interesting relationships between the other features (not the main feature(s) of interest)?
#
# Yes, several interesting relationships between features other than the main features of interest were observed during the investigation:
#
# 1. **User Type and Start Hour**:
#    - **Observation**: When examining the distribution of trip start times by user type, it was observed that subscribers predominantly start their trips during peak commuting hours (7-9 AM and 4-6 PM), while customers have a more even distribution of trip start times throughout the day.
#    - **Insight**: This indicates that subscribers are more likely to use the bike-sharing service for regular commuting purposes, whereas customers may use it for leisure or irregular trips.
#
# 2. **Start Station and User Type**:
#    - **Observation**: Analysis of the most popular start stations showed that certain stations are predominantly used by subscribers, while others are more frequently used by customers.
#    - **Insight**: This suggests that certain locations might cater more to regular commuters (subscribers) while others might be more attractive to tourists or occasional users (customers). This can inform decisions on bike distribution and station placement.
#
# 3. **Age and Trip Frequency**:
#    - **Observation**: There was a noticeable trend in the data showing that younger users (in their 20s and 30s) tend to take more trips compared to older users.
#    - **Insight**: Younger adults are more frequent users of the bike-sharing service, which could be due to factors such as commuting needs, physical fitness, or lifestyle preferences. This demographic insight can help in tailoring promotional activities and service offerings.
#
# 4. **Gender and User Type**:
#    - **Observation**: The proportion of male users is higher among subscribers compared to customers, while the proportion of female users is relatively higher among customers.
#    - **Insight**: This indicates that male users are more likely to subscribe to the service for regular use, whereas female users might prefer to use the service on a more casual basis. Understanding this gender-based preference can help in customizing marketing strategies and service features.
#
# These additional insights complement the main findings and provide a more comprehensive understanding of the user behavior and usage patterns of the bike-sharing service. They can be valuable for improving service delivery, optimizing bike availability, and designing targeted marketing campaigns.

# %% [markdown]
# ## Multivariate Exploration
#
# > Create plots of three or more variables to investigate your data even
# further. Make sure that your investigations are justified, and follow from
# your work in the previous sections.

# %% [markdown]
# ### Question 1: How does trip duration vary with age and gender?

# %%
import seaborn as sb
import matplotlib.pyplot as plt

# Function to set labels and title
def set_labels(x_label, y_label, title):
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)

# Scatter plot of trip duration vs. age, colored by gender
plt.figure(figsize=(12, 6))
sb.scatterplot(data=data, x='age', y='duration_sec', hue='member_gender', alpha=0.5)
set_labels('Age', 'Trip Duration (seconds)', 'Trip Duration vs. Age by Gender')
plt.ylim(0, 3600)  # Limiting to 1 hour for better visualization
plt.show()

# %% [markdown]
# ### Observation: Trip Duration vs. Age by Gender
#
# The scatter plot visualizes the relationship between trip duration and age, colored by gender.
#
# - **Distribution Across Genders**: The plot shows that males, females, and other genders are represented across all ages.
# - **Trip Duration Consistency**: Trip durations tend to be shorter for all age groups, with most trips being under 1000 seconds (approximately 16.67 minutes).
# - **Age Outliers**: There are some outliers in age, particularly individuals over 100 years old, which may indicate data entry errors.
# - **Gender Representation**: Males appear to have a higher frequency across all age groups compared to females and other genders.
#
# ### Interpretation:
# The scatter plot indicates that the trip durations are fairly consistent across different age groups and genders. Most users, regardless of age and gender, have trips that last under 1000 seconds. The higher frequency of males could suggest that they are more frequent users of the service.
#
# ### Further Analysis:
# To gain deeper insights, we could examine:
# - The average trip duration by age group and gender to identify any subtle differences.
# - The time of day when different genders are most active to understand peak usage periods for each gender.
# - The start and end locations of trips for different age groups and genders to identify popular routes and areas.

# %% [markdown]
# Question 2: How does user type, start hour, and trip duration interact?

# %%
import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd

# Function to set labels and title
def set_labels(x_label, y_label, title):
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)

# Extracting start hour and day of week from start_time
data['start_time'] = pd.to_datetime(data['start_time'])
data['start_hour'] = data['start_time'].dt.hour
data['start_day'] = data['start_time'].dt.day_name()

# Pivot table to calculate the mean trip duration for each combination of start hour and start day
pivot_table = data.pivot_table(values='duration_sec', index='start_hour', columns='start_day', aggfunc='mean')

# Reordering columns to show days of the week in order
pivot_table = pivot_table[['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']]

# Plotting the heatmap
plt.figure(figsize=(12, 6))
sb.heatmap(pivot_table, cmap='YlGnBu', annot=True, fmt=".1f")
set_labels('Day of the Week', 'Hour of the Day', 'Average Trip Duration by Hour and Day')
plt.show()

# %% [markdown]
# ### Observation
#
# The heatmap displays the average trip duration in seconds, based on the start hour and the day of the week. Here are some key observations:
#
# 1. **Peak Hours on Weekdays**:
#    - The average trip duration is higher during the morning (8-9 AM) and evening (5-6 PM) peak hours on weekdays. This indicates that many users are utilizing the bike-sharing system for commuting purposes.
#
# 2. **Shorter Trips During Midday**:
#    - During the midday hours (10 AM - 4 PM), the trip durations are generally shorter. This could be due to less traffic and more efficient trips during these hours.
#
# 3. **Weekend Patterns**:
#    - On weekends, especially Saturday and Sunday, there are no pronounced peak hours. The average trip duration is more evenly distributed throughout the day, suggesting leisure trips rather than commuting.
#
# 4. **Variations in Trip Duration**:
#    - Trip durations vary not only by time of day but also by day of the week. For example, Thursdays have notably higher trip durations, which could be due to specific weekly events or patterns.
#
# These observations help in understanding user behavior and can be useful for optimizing the operation of the bike-sharing system to manage peak hour demand and improve service during quieter hours.

# %% [markdown]
# Question 3: How do age, gender, and user type relate to trip duration?

# %%
# Create age bins
bins = [0, 20, 30, 40, 50, 60, 70, 80, 90, 100]
labels = ['<20', '20-29', '30-39', '40-49', '50-59', '60-69', '70-79', '80-89', '90-99']
data['age_bin'] = pd.cut(data['age'], bins=bins, labels=labels, right=False)

# Violin plot of trip duration by age bin, separated by gender and user type
plt.figure(figsize=(12, 6))
sb.violinplot(data=data, x='age_bin', y='duration_sec', hue='user_type', split=True, inner='quartile')
plt.xlabel('Age Bin')
plt.ylabel('Trip Duration (seconds)')
plt.title('Trip Duration by Age Bin, Gender, and User Type')
plt.ylim(0, 3600)  # Limiting to 1 hour for better visualization
plt.show()

# %% [markdown]
# ### Observation
#
# The violin plot visualizes the distribution of trip durations for different age groups, separated by gender and user type (Subscriber or Customer). Here are some key observations:
#
# 1. **Age Group Differences**:
#    - The trip duration distribution is quite similar across the different age groups, with slight variations.
#    - Users in the 20-29 and 30-39 age groups have the most pronounced distribution, indicating higher usage among these groups.
#
# 2. **User Type Variations**:
#    - Subscribers tend to have shorter trip durations compared to Customers. This pattern is consistent across all age groups.
#    - This suggests that Subscribers, who are likely using the service more regularly, tend to use the bikes for shorter, more routine trips.
#
# 3. **Gender Differences**:
#    - The plot does not show significant differences in trip duration between genders within each age group and user type.
#    - This implies that the usage pattern in terms of trip duration is relatively consistent across genders.
#
# These insights can help in understanding the usage patterns and preferences of different user segments, which can be valuable for targeted marketing and service optimization.

# %% [markdown]
# Question 5: What are the most common routes taken by different user types?

# %%
# Bar plot of the top 10 most common routes (start and end station pairs) by user type
data['route'] = data['start_station_name'] + ' to ' + data['end_station_name']
top_routes = data['route'].value_counts().head(10).index

plt.figure(figsize=(12, 6))
sb.countplot(data=data[data['route'].isin(top_routes)], y='route', hue='user_type', palette='Set2')
plt.xlabel('Count')
plt.ylabel('Route')
plt.title('Top 10 Most Common Routes by User Type')
plt.show()

# %% [markdown]
# ### Observation
#
# The bar plot visualizes the top 10 most common routes (start and end station pairs) and distinguishes the counts by user type (Subscriber or Customer). Here are some key observations:
#
# 1. **Popular Routes**:
#    - Certain routes are significantly more popular, indicating key areas of high demand.
#    - The most frequent routes are likely in central or well-connected locations.
#
# 2. **User Type Differences**:
#    - Subscribers dominate the majority of the top routes, suggesting they are more frequent users of the service.
#    - This pattern is consistent across all the top 10 routes, with Subscribers showing higher counts than Customers.
#
# 3. **Route Preferences**:
#    - The preferences for routes are similar between Subscribers and Customers, but the volume of trips is higher for Subscribers.
#    - This might imply that Subscribers, who are regular users, prefer similar routes for their daily commutes or regular activities.
#
# These insights can help in understanding the demand patterns for different routes and can guide decisions related to bike placement, route optimization, and targeted services for different user types.

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. Were there features that strengthened each other in terms of looking at your feature(s) of interest?
#
# > Your answer here!### Talk about some of the relationships you observed in this part of the investigation. Were there features that strengthened each other in terms of looking at your feature(s) of interest?
#
#
# In this section, we examined various relationships between features to understand how they interact with each other. Here are some key observations:
#
# 1. **Trip Duration and Age**:
#    - Younger users (aged 20-30) tend to have shorter trip durations compared to older users.
#    - There is a slight increase in trip duration for users in their 50s and 60s, possibly due to leisure trips rather than commutes.
#
# 2. **Trip Duration and User Type**:
#    - Subscribers generally have shorter trip durations compared to Customers. This could be due to Subscribers using the service for regular commutes, which are typically shorter.
#    - Customers, on the other hand, might use the service for longer, more leisurely trips or occasional use.
#
# 3. **Trip Start Time and Duration**:
#    - The trip duration varies significantly with the time of day. Early morning and late evening trips tend to be longer.
#    - This pattern suggests that trips taken during off-peak hours are less hurried and possibly more leisurely.
#
# 4. **Gender and Age Distribution**:
#    - The age distribution is fairly consistent across genders, with most users being in their 20s and 30s.
#    - Male users have a slightly broader age range compared to female users.
#
# 5. **Popular Routes and User Type**:
#    - Certain routes are more popular among all users, but Subscribers dominate these routes in terms of frequency.
#    - This indicates that Subscribers likely use the service for regular commutes along these popular routes.
#
# These relationships provide a deeper understanding of user behavior and preferences. The consistency in findings, such as the shorter trip durations for Subscribers and the higher usage by younger adults, helps in reinforcing our understanding of the primary user base and their patterns. This information is crucial for optimizing service deployment, targeting marketing efforts, and enhancing user experience based on specific needs and preferences.
#
#
#
# ### Were there any interesting or surprising interactions between features?
#
#
#
# During the exploration of relationships between different features in the dataset, several interesting and surprising interactions were observed:
#
# 1. **Age and Trip Duration**:
#    - It was surprising to observe that older users (above 60) still actively use the bike-sharing service. Although their numbers are fewer, their presence indicates that bike-sharing is not limited to just younger adults.
#
# 2. **Gender and Trip Duration**:
#    - Trip durations were relatively consistent across different genders, which was unexpected. This suggests that both male and female users have similar usage patterns in terms of trip length, challenging any preconceived notions about gender differences in bike usage.
#
# 3. **User Type and Trip Duration**:
#    - The clear distinction in trip durations between Subscribers and Customers was notable. Subscribers generally take shorter trips, reinforcing the idea that they use the service primarily for commuting. In contrast, Customers tend to take longer trips, possibly for leisure or occasional use.
#
# 4. **Hour of the Day and Trip Duration**:
#    - The peak usage hours (8 AM and 5 PM) correlate with standard commuting times. However, the fact that trips during off-peak hours (early morning and late evening) are longer was surprising. This suggests that users are more relaxed and take longer rides outside of rush hours.
#
# 5. **Day of the Week and Trip Duration**:
#    - Weekends (Saturday and Sunday) have fewer trips compared to weekdays, but the trips tend to be longer. This indicates that weekend trips are likely more recreational, whereas weekday trips are more utilitarian.
#
# 6. **Heatmap of Trip Duration by Hour and Day**:
#    - The heatmap revealed that trip durations are longest during early morning hours on weekends, particularly Sunday. This could be due to users taking leisure rides or participating in long-distance biking activities during these times.
#
# These interactions highlight the diverse ways in which different user groups utilize the bike-sharing service. Understanding these patterns can help in tailoring the service to better meet the needs of different user segments, such as offering targeted promotions or adjusting bike availability based on peak usage times and user preferences.

# %% [markdown]
# ## Conclusions
#
# ## Conclusion
#
# ### Summary of Findings
# - **User Demographics**:
#   - The majority of Ford GoBike users are younger adults, primarily between the ages of 20 and 40. The highest user frequency is around 30 years old.
#   - There is a significant gender imbalance, with male users representing the majority, followed by female users and a small proportion of users identifying as other.
# - **Trip Duration**:
#   - Most trips are short, typically under 10 minutes, indicating that the bike-sharing service is used mainly for quick commutes.
#   - Subscribers tend to take shorter trips compared to Customers, who generally have longer trip durations.
# - **Peak Usage Times**:
#   - The peak hours for bike usage are during the morning and evening rush hours (8 AM and 5 PM), correlating with typical commuting times.
#   - There is a noticeable decrease in trips during the middle of the day and late at night.
# - **Popular Routes and Stations**:
#   - The most popular start stations are centrally located and well-connected transit hubs.
#   - The top 10 most common routes are heavily utilized by both Subscribers and Customers, with Subscribers showing a higher frequency of usage.
# - **Interesting Interactions**:
#   - Older users, though fewer in number, still actively use the service, indicating a broad age range of users.
#   - Gender differences in trip duration are minimal, suggesting similar usage patterns across genders.
#   - Weekend trips tend to be longer, likely indicating recreational use, whereas weekday trips are shorter and more utilitarian.
#
# ### Reflections
# The data exploration has provided valuable insights into the usage patterns of the Ford GoBike service. Understanding user demographics, trip durations, peak usage times, and popular routes can help optimize the service to better meet user needs. For instance, the service can:
# - Adjust bike availability during peak hours and at popular stations.
# - Offer targeted promotions to encourage more balanced gender participation.
# - Cater to the recreational needs of weekend users with special offers or events.
#
# ### Future Work
# To further enhance the analysis and provide deeper insights, future work could include:
# - Analyzing trip distances in addition to durations.
# - Examining the impact of weather conditions on bike usage.
# - Investigating the usage patterns of different subscription types in more detail.
# - Exploring the geographical distribution of trips to identify potential areas for service expansion.
#
# By continuing to analyze and understand user behavior, the Ford GoBike service can improve its offerings and ensure a better experience for all its users.

# %% [markdown]
# > Remove all Tips mentioned above, before you convert this notebook to PDF/HTML
#
#
# > At the end of your report, make sure that you export the notebook as an
# html file from the `File > Download as... > HTML` menu. Make sure you keep
# track of where the exported file goes, so you can put it in the same folder
# as this notebook for project submission. Also, make sure you remove all of
# the quote-formatted guide notes like this one before you finish your report!
